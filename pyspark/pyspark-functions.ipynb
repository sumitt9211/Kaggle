# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# create a SparkSession
spark = SparkSession.builder.appName("CreateDataFrameExample").getOrCreate()

# define the schema of the dataframe
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/19 17:52:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# /opt/conda/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)

# %% [markdown]
# # **Create DataFrame**

# %%
schema = StructType([
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("city", StringType(), True)
])

# define the data
data = [("Alice", 25, "New York"),
        ("Bob", 30, "San Francisco"),
        ("Charlie", 35, "London")]

# create a dataframe
df = spark.createDataFrame(data, schema)

# show the dataframe
df.show()
# Out:
# +-------+---+-------------+
# |   name|age|         city|
# +-------+---+-------------+
# |  Alice| 25|     New York|
# |    Bob| 30|San Francisco|
# |Charlie| 35|       London|
# +-------+---+-------------+

# %%
# read a CSV file
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/kaggle/input/int-trhist/Int_TrHist.csv")

# show the data
df.toPandas()
# Out:
#         Item Number                               Item Description  \
# 0            0-0033                          AVOCADO OIL-PRESERVED
# 1            0-0033                          AVOCADO OIL-PRESERVED
# 2            0-0033                          AVOCADO OIL-PRESERVED
# 3            0-0033                          AVOCADO OIL-PRESERVED
# 4            0-0033                          AVOCADO OIL-PRESERVED
# ...             ...                                            ...
# 30937  WCC800000023   SHADE LABEL GENEROUS  COMP-W POWDER KISS L/S
# 30938  WCC800000024  SHADE LABEL GENEROUS CARTON-W POWDER KISS L/S
# 30939  WCC800000024  SHADE LABEL GENEROUS CARTON-W POWDER KISS L/S
# 30940  WCC800000025  SHADE LABE ENIGMATIC CARTON-W POWDER KISS L/S
# 30941  WCC800000025  SHADE LABE ENIGMATIC CARTON-W POWDER KISS L/S
#
#        Transaction Number Transaction Type        Date                Time  \
# 0                   70977          ISS-CHL  22-12-2022 2023-04-19 17:41:00
# 1                   70978          RCT-CHL  22-12-2022 2023-04-19 17:41:00
# 2                   71683         CYC-RCNT  29-12-2022 2023-04-19 17:45:00
# 3                   71684         CYC-RCNT  29-12-2022 2023-04-19 17:47:00
# 4                   71922         CYC-RCNT  31-12-2022 2023-04-19 10:19:00
# ...                   ...              ...         ...                 ...
# 30937              104279           RCT-TR  19-04-2023 2023-04-19 09:23:00
# 30938               95127          ISS-CHL  14-03-2023 2023-04-19 11:45:00
# 30939               95128          RCT-CHL  14-03-2023 2023-04-19 11:45:00
# 30940               95129          ISS-CHL  14-03-2023 2023-04-19 11:46:00
# 30941               95130          RCT-CHL  14-03-2023 2023-04-19 11:46:00
#
#       Site Location       Lot/Serial Reference  ... Shipper Number Address  \
# 0      DDN  RM01C16  20201229RM16626      None  ...           None    None
# 1      DDN  RM01C16  20201229RM16626      None  ...           None    None
# 2      DDN  RM01C16  20201229RM16626      None  ...           None    None
# 3      DDN  RM01C16  20201229RM16626      None  ...           None    None
# 4      DDN  RM01C16  20201229RM16626      None  ...           None    None
# ...    ...      ...              ...       ...  ...            ...     ...
# 30937  DDN  FG03A05  20220922PM17983      None  ...           None    None
# 30938  DDN    LC132  20220922PM17984      None  ...           None    None
# 30939  DDN    LC132  20220922PM17984      None  ...           None    None
# 30940  DDN    LC131  20220922PM17985      None  ...           None    None
# 30941  DDN    LC131  20220922PM17985      None  ...           None    None
#
#        Supplier Lot  Grade Assay Percentage Expire Date     Program   User ID  \
# 0              None     RT            0.00%  29-12-2022   icitlmt.p    kumarm
# 1              None     RT            0.00%  22-06-2023   icitlmt.p    kumarm
# 2              None     RT            0.00%  22-06-2023    icccaj.p      alir
# 3              None     RT            0.00%  22-06-2023    icccaj.p      alir
# 4              None     RT            0.00%  22-06-2023    icccaj.p  samkaria
# ...             ...    ...              ...         ...         ...       ...
# 30937          None   None            0.00%  21-09-2024  iclotr02.p   vermash
# 30938          None   None            0.00%  22-09-2025   icitlmt.p      rajt
# 30939          None   None            0.00%  21-09-2024   icitlmt.p      rajt
# 30940          None   None            0.00%  22-09-2025   icitlmt.p      rajt
# 30941          None   None            0.00%  21-09-2024   icitlmt.p      rajt
#
#                   Remarks    Domain
# 0                    None  Intercos
# 1                    None  Intercos
# 2               CYC Count  Intercos
# 3               CYC Count  Intercos
# 4      Raza doing testing  Intercos
# ...                   ...       ...
# 30937                None  Intercos
# 30938                None  Intercos
# 30939                None  Intercos
# 30940                None  Intercos
# 30941                None  Intercos
#
# [30942 rows x 38 columns]
